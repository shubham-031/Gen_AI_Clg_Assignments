# %% [markdown]
# # Prompt Engineering Approaches
#
# This notebook implements and compares different Prompt Engineering techniques using Gemini.

# %% [markdown]
# ## 1. Setup

# %%
import os
from google import genai

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

def call_gemini(prompt):
    response = client.models.generate_content(
        model="models/gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %% [markdown]
# ## 2. Interview Style Prompt

# %%
interview_response = call_gemini(
    "Answer like in a technical interview: Explain Artificial Intelligence."
)
print(interview_response)
# Out:
# Alright, let's break down Artificial Intelligence in a way that demonstrates a solid understanding for a technical interview.
#
# ---
#
# "Artificial Intelligence, or AI, is a broad and transformative field of computer science focused on creating machines that can perform tasks that typically require human intelligence. At its core, AI aims to enable computers to *perceive, reason, learn, understand, and act* in complex environments.
#
# **Core Goals & Capabilities:**
# The overarching goals of AI include:
#
# 1.  **Learning:** Acquiring knowledge and skills from data without explicit programming.
# 2.  **Reasoning:** Applying logic, rules, and common sense to infer conclusions and solve problems.
# 3.  **Problem-Solving:** Devising strategies to achieve goals, often in novel situations.
# 4.  **Perception:** Interpreting sensory information, such as images (Computer Vision) and sounds.
# 5.  **Natural Language Understanding:** Processing and generating human language (Natural Language Processing - NLP).
# 6.  **Knowledge Representation:** Storing and managing information effectively.
#
# **Key Subfields and Paradigms:**
# While AI is the umbrella term, several critical subfields drive its practical applications:
#
# *   **Machine Learning (ML):** This is arguably the most dominant paradigm in AI today. ML focuses on algorithms that learn from data, identify patterns, and make predictions or decisions without being explicitly programmed for every scenario. Key types include:
#     *   **Supervised Learning:** Training models on labeled data (input-output pairs) to predict future outcomes (e.g., classification, regression).
#     *   **Unsupervised Learning:** Finding hidden patterns or structures in unlabeled data (e.g., clustering, dimensionality reduction).
#     *   **Reinforcement Learning:** Training agents to make sequential decisions in an environment to maximize a reward signal (e.g., game playing, robotics control).
#
# *   **Deep Learning (DL):** A specialized subset of Machine Learning that uses artificial neural networks with multiple layers (hence 'deep') to learn complex, hierarchical patterns directly from raw data. Deep learning has driven breakthroughs in areas like computer vision, speech recognition, and natural language understanding due to its ability to automatically learn features.
#
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language. This includes tasks like sentiment analysis, machine translation, chatbots, and text summarization.
#
# *   **Computer Vision (CV):** Allows computers to 'see,' interpret, and understand visual information from the world, such as images and videos. Applications include object detection, facial recognition, medical image analysis, and autonomous driving.
#
# *   **Robotics:** Integrates AI with physical systems to enable robots to perceive their environment, plan actions, and execute tasks autonomously or semi-autonomously.
#
# **How AI Systems Work (General Principles):**
# At a high level, the development and deployment of most modern AI systems typically involve:
#
# 1.  **Data Collection and Preparation:** Gathering vast amounts of relevant data, cleaning it, and transforming it into a usable format. This data is the fuel for learning.
# 2.  **Algorithm Selection:** Choosing appropriate algorithms based on the problem type (e.g., neural networks for image recognition, decision trees for classification).
# 3.  **Model Training:** Feeding the prepared data into the chosen algorithms to learn patterns and build a predictive or decision-making model.
# 4.  **Evaluation and Iteration:** Testing the trained model on new, unseen data to assess its performance, identify biases, and iterate on the training process to improve accuracy and robustness.
# 5.  **Deployment and Monitoring:** Integrating the trained model into real-world applications and continuously monitoring its performance, especially in dynamic environments.
#
# **Types of AI (Scope of Intelligence):**
#
# *   **Narrow AI (or Weak AI):** This is virtually all the AI we encounter today. It's designed and trained for a specific, single task (e.g., playing chess, recommending products, facial recognition, powering voice assistants like Siri). It excels at its defined task but lacks broader cognitive abilities.
# *   **General AI (or Strong AI / AGI):** This is a hypothetical AI that possesses the ability to understand, learn, and apply intelligence to *any intellectual task* a human being can. It would exhibit common sense, learn from experience across diverse domains, and transfer knowledge between different problems. We are currently far from achieving AGI.
#
# **Real-World Applications:**
# AI is already transforming numerous industries:
#
# *   **Healthcare:** Drug discovery, diagnostic assistance, personalized medicine, predictive analytics for outbreaks.
# *   **Finance:** Fraud detection, algorithmic trading, credit scoring, risk assessment.
# *   **Transportation:** Self-driving cars, traffic optimization, logistics and supply chain management.
# *   **Customer Service:** Chatbots, virtual assistants, personalized recommendations.
# *   **Manufacturing:** Predictive maintenance, quality control, robotic automation.
#
# **Challenges and Future Directions:**
# Despite its power, AI faces significant challenges:
#
# *   **Data Quality and Bias:** AI models are only as good as the data they're trained on. Biased or insufficient data can lead to unfair or inaccurate outcomes.
# *   **Explainability (XAI):** Understanding *why* an AI model made a particular decision, especially in 'black box' deep learning models, is crucial for trust and compliance.
# *   **Ethical Considerations:** Addressing issues of privacy, security, job displacement, and the responsible use of autonomous systems.
# *   **Computational Cost:** Training large, complex AI models requires substantial computing resources.
# *   **Robustness and Generalization:** Ensuring models perform reliably and generalize well to new, unseen data in real-world, often unpredictable, environments.
#
# The future of AI involves not just pushing the boundaries towards more general intelligence, but also focusing on creating more responsible, interpretable, and human-centric AI systems that augment human capabilities rather than simply replacing them."

# %% [markdown]
# ## 3. Chain of Thought (CoT)

# %%
cot_response = call_gemini(
    "Explain Artificial Intelligence step by step using logical reasoning."
)
print(cot_response)
# Out:
# Artificial Intelligence (AI) can be understood as the endeavor to enable machines to perform tasks that typically require human intelligence. Let's break it down step-by-step using logical reasoning.
#
# ---
#
# ### Step 1: Defining "Intelligence" in a Machine Context (The Goal)
#
# *   **Logical Premise:** Humans perform various tasks that we consider "intelligent," such as problem-solving, understanding language, recognizing patterns, learning from experience, making decisions, and adapting to new situations.
# *   **Logical Deduction:** If we want machines to exhibit "intelligence," they must be capable of performing these kinds of tasks. We are not necessarily trying to *replicate* human consciousness or emotion, but rather *simulate* the cognitive functions associated with intelligence to achieve specific goals.
# *   **Conclusion:** The initial logical step in AI is to define what specific intelligent behaviors we want a machine to emulate.
#
# ---
#
# ### Step 2: Representing the World (Input for the Machine)
#
# *   **Logical Premise:** A human needs information about the world to act intelligently. For example, to play chess, you need to see the board. To answer a question, you need to understand the question and have relevant knowledge.
# *   **Logical Deduction:** A machine, similarly, cannot be intelligent in a vacuum. It needs data and a way to understand or structure that data. This means converting real-world information (images, text, numbers, sounds) into a format a computer can process. This is called **data representation**.
# *   **Conclusion:** Before a machine can "think" or "act," it must have a structured understanding of the relevant aspects of its environment or problem domain.
#
# ---
#
# ### Step 3: Giving the Machine "Rules" (Early AI & Problem Solving)
#
# *   **Logical Premise:** Once a machine has data, it needs instructions on what to *do* with it. In many well-defined problems, human experts already know the rules or steps to solve them.
# *   **Logical Deduction:** We can program these explicit rules and logical steps into the machine. For instance, in a chess game, "If your king is under attack, move it to safety." In a medical diagnosis system, "If symptoms A, B, and C are present, then suspect condition X." This forms **rule-based systems** or **expert systems**.
# *   **Conclusion:** For problems where the rules are clear and finite, we can make machines appear intelligent by directly programming them with these rules and algorithms to process information and arrive at solutions.
#
# ---
#
# ### Step 4: When Rules Aren't Enough – Learning from Experience (Machine Learning)
#
# *   **Logical Premise:** Many real-world problems (like recognizing a face, understanding natural speech, or predicting stock prices) are too complex to define with explicit, exhaustive rules. The patterns are subtle, change over time, or are simply too numerous for a human to program manually.
# *   **Logical Deduction:** If we can't *tell* the machine all the rules, the logical next step is to enable the machine to *discover* these rules or patterns on its own by looking at vast amounts of examples. This is the core idea of **Machine Learning (ML)**. Instead of programming "how to recognize a cat," we show it thousands of images labeled "cat" and "not-cat," and it learns the distinguishing features.
# *   **Conclusion:** When explicit rule-based programming becomes impractical, we shift to letting machines learn patterns and make predictions from data, effectively allowing them to derive their own "rules" or models.
#
# ---
#
# ### Step 5: Learning Complex Patterns – The Layers of Abstraction (Deep Learning)
#
# *   **Logical Premise:** While traditional Machine Learning algorithms (like decision trees or support vector machines) are powerful, they often struggle with raw, unstructured data like pixel values in an image or raw audio waveforms. They might need humans to manually identify "features" (e.g., "does this image have eyes?").
# *   **Logical Deduction:** The next logical evolution is to allow the machine to automatically learn increasingly complex and abstract features directly from the raw data. This is achieved through **Deep Learning (DL)**, a subset of ML that uses artificial neural networks with many layers (hence "deep"). Each layer learns to recognize different levels of abstraction – one layer might detect edges, the next shapes, and a higher layer might detect entire objects.
# *   **Conclusion:** Deep Learning enables machines to process highly complex, raw data by building hierarchical representations, automatically discovering the most relevant features necessary for a given task, making it incredibly effective for perception-based AI (vision, speech).
#
# ---
#
# ### Step 6: Acting on Knowledge (Inference & Decision Making)
#
# *   **Logical Premise:** Whether a machine has been programmed with rules (Step 3) or has learned patterns from data (Step 4 & 5), the ultimate goal is for it to *do* something intelligent when presented with new, unseen information.
# *   **Logical Deduction:** When a new input comes in (e.g., a new image, a new question, a new set of sensor readings), the AI system uses its acquired knowledge (rules or learned models) to process this input and generate an output. This could be:
#     *   **Classification:** "This image contains a dog."
#     *   **Prediction:** "The temperature will be 25°C tomorrow."
#     *   **Action:** "Turn the steering wheel left."
#     *   **Generation:** "Here is a summary of the article."
#     This process is called **inference** or **making a decision**.
# *   **Conclusion:** The final logical step is the application of the machine's learned or programmed intelligence to perform a specific task or make a decision in real-time based on new data.
#
# ---
#
# ### Step 7: The Cycle of Improvement and Integration (Building Smarter Systems)
#
# *   **Logical Premise:** AI systems don't always get it right the first time, and the world is constantly changing.
# *   **Logical Deduction:** For true intelligence and robustness, AI systems often need mechanisms for:
#     *   **Feedback and Refinement:** Learning from mistakes and continuously improving their models with new data.
#     *   **Integration:** Combining multiple AI components (e.g., a self-driving car needs vision, planning, decision-making, natural language processing for voice commands).
#     *   **Adaptation:** Adjusting to new environments or unforeseen circumstances.
# *   **Conclusion:** AI is an iterative process. Systems are designed to learn, act, receive feedback, and refine their intelligence over time, often integrating various AI techniques into a cohesive, intelligent agent capable of tackling complex, real-world problems.
#
# ---
#
# By following these logical steps, we build a comprehensive understanding of how Artificial Intelligence progresses from a conceptual goal to sophisticated, problem-solving machines.

# %% [markdown]
# ## 4. Tree of Thought (ToT)

# %%
tot_response = call_gemini(
    "Explain Artificial Intelligence by exploring multiple solution paths and comparing them."
)
print(tot_response)
# Out:
# Artificial Intelligence (AI) isn't a single "thing" but rather a vast field aiming to create machines that can perform tasks traditionally requiring human intelligence. The fundamental challenge of *how* to achieve this "intelligence" has led to several distinct **solution paths** or paradigms over the decades, each with its own philosophy, strengths, and weaknesses.
#
# Let's explore these major paths, comparing their approaches to building intelligent systems.
#
# ---
#
# ## What is AI? A Quick Foundation
#
# Before diving into the paths, it's helpful to understand the core goals of AI:
#
# 1.  **Thinking Humanly:** Building systems that think like humans (e.g., cognitive modeling).
# 2.  **Acting Humanly:** Building systems that act like humans (e.g., passing the Turing Test).
# 3.  **Thinking Rationally:** Building systems that think "correctly" based on logic.
# 4.  **Acting Rationally:** Building systems that act to achieve the best outcome.
#
# Most modern AI falls under "acting rationally," often by learning from data or following predefined rules to make optimal decisions. We also distinguish between:
#
# *   **Narrow AI (ANI):** AI designed and trained for a specific task (e.g., chess program, facial recognition). This is what we have today.
# *   **General AI (AGI):** Hypothetical AI that can understand, learn, and apply intelligence to any intellectual task a human can.
# *   **Superintelligence (ASI):** Hypothetical AI that surpasses human intelligence.
#
# Now, let's explore the "how."
#
# ---
#
# ## Solution Paths to Artificial Intelligence
#
# ### Path 1: Symbolic AI / Rule-Based Systems (Good Old-Fashioned AI - GOFAI)
#
# *   **Core Idea/Philosophy:** This approach, dominant from the 1950s to the 1980s, posits that intelligence can be achieved by explicitly representing knowledge using symbols and manipulating those symbols with logical rules. It aims to model high-level human reasoning processes. Think of it as programming "common sense" and expert knowledge directly.
# *   **How it Works:**
#     *   **Knowledge Representation:** Facts about the world are encoded as symbols and relationships (e.g., "Socrates IS_A Man," "Man IS_MORTAL"). This forms a knowledge base.
#     *   **Logical Inference:** Rules (e.g., "IF X IS_A Y AND Y IS_MORTAL THEN X IS_MORTAL") are applied to the knowledge base to deduce new facts or answer queries.
#     *   **Search Algorithms:** Used to navigate state spaces (e.g., in chess, planning problems) to find a solution.
# *   **Key Techniques:** Expert Systems, Knowledge Graphs, Prolog (logic programming), A* search, Minimax.
# *   **Strengths:**
#     *   **Explainability:** Decisions are often transparent and traceable through the explicit rules.
#     *   **Logical Rigor:** Excellent for problems that can be clearly defined with logical rules and discrete states.
#     *   **Requires Less Data:** Can function with a carefully curated knowledge base without vast datasets.
# *   **Weaknesses:**
#     *   **Brittleness:** Struggles with ambiguity, exceptions, and "common sense" knowledge that is hard to formalize.
#     *   **Scalability:** Manual knowledge engineering is labor-intensive and difficult to scale to complex real-world domains.
#     *   **Learning Difficulty:** Not inherently designed to learn from experience; requires human updates to its knowledge base.
# *   **Real-world Examples:** Early medical diagnosis systems (like MYCIN), early chess programs, some industrial control systems, knowledge graphs used in search engines.
#
# **Comparison:** Symbolic AI is like building a meticulously crafted, explicit instruction manual for intelligence. It excels where the rules are clear, but struggles where knowledge is vague, vast, or learned implicitly.
#
# ---
#
# ### Path 2: Connectionism / Machine Learning (Data-Driven AI)
#
# *   **Core Idea/Philosophy:** Inspired by the structure and function of the human brain, this path posits that intelligence emerges from learning patterns and relationships directly from data, rather than being explicitly programmed. It focuses on adaptive systems that can "learn by example."
# *   **How it Works:**
#     *   **Neural Networks:** Interconnected "neurons" that process information. Connections between neurons have "weights" that are adjusted during a training process.
#     *   **Training Data:** The system is fed vast amounts of data (e.g., images, text, audio) labeled with correct outputs.
#     *   **Pattern Recognition:** The network learns to identify complex patterns and make predictions or classifications without explicit rules.
#     *   **Deep Learning:** A subfield using neural networks with many layers (deep networks) to learn hierarchical features.
# *   **Key Techniques:** Artificial Neural Networks (ANNs), Convolutional Neural Networks (CNNs), Recurrent Neural Networks (RNNs), Transformers, Support Vector Machines (SVMs), Decision Trees, Reinforcement Learning.
# *   **Strengths:**
#     *   **Adaptability & Learning:** Excels at tasks involving pattern recognition, prediction, and handling noisy or complex data.
#     *   **Scalability (with Data):** Performance often improves with more data.
#     *   **Handles Ambiguity:** Can generalize and make predictions even with incomplete or slightly different inputs.
#     *   **Automatic Feature Extraction:** Deep learning can discover relevant features automatically, reducing manual effort.
# *   **Weaknesses:**
#     *   **Black Box Problem:** Many models (especially deep learning) are hard to interpret; it's difficult to understand *why* a particular decision was made.
#     *   **Data Hunger:** Requires massive amounts of labeled data for effective training, which can be expensive or unavailable.
#     *   **Computational Cost:** Training large models requires significant processing power.
#     *   **Bias:** Can perpetuate and amplify biases present in the training data.
# *   **Real-world Examples:** Image recognition (facial recognition, self-driving cars), natural language processing (ChatGPT, Google Translate), recommendation systems (Netflix, Amazon), speech recognition (Siri, Alexa), spam detection.
#
# **Comparison:** Connectionism is like giving a child many examples and letting them figure out the rules for themselves. It's powerful for perception and pattern recognition but often lacks the inherent transparency and logical guarantees of symbolic systems.
#
# ---
#
# ### Path 3: Evolutionary Computation (Bio-Inspired Optimization)
#
# *   **Core Idea/Philosophy:** This path takes inspiration from natural selection and evolution to solve complex optimization and search problems. It doesn't aim to directly model human intelligence but rather to develop robust problem-solving mechanisms.
# *   **How it Works:**
#     *   **Population of Solutions:** Starts with a random set of potential solutions (individuals).
#     *   **Fitness Function:** Each individual is evaluated based on how well it solves the problem (its "fitness").
#     *   **Selection:** Individuals with higher fitness are more likely to be selected to reproduce.
#     *   **Genetic Operators:** Selected individuals undergo "mutation" (random changes) and "crossover" (combining features of two parents) to create new offspring.
#     *   **Iteration:** This process repeats over many generations, with the population gradually evolving towards better solutions.
# *   **Key Techniques:** Genetic Algorithms (GAs), Genetic Programming (GP), Evolutionary Strategies, Swarm Intelligence (e.g., Particle Swarm Optimization, Ant Colony Optimization).
# *   **Strengths:**
#     *   **Exploration of Complex Spaces:** Excellent for problems with vast, non-linear search spaces where traditional optimization methods struggle.
#     *   **Robustness:** Can find good solutions even in noisy or incomplete environments.
#     *   **Novelty:** Can discover unexpected or innovative solutions.
#     *   **Parallelizable:** Many operations can be performed in parallel.
# *   **Weaknesses:**
#     *   **Computational Cost:** Can be very slow and require many generations to converge.
#     *   **No Guarantee of Optimality:** May find a "good enough" solution, but not necessarily the absolute best (global optimum).
#     *   **Parameter Tuning:** Performance is sensitive to the choice of genetic operators and their parameters.
#     *   **Interpretation:** It can be hard to understand *why* a particular evolved solution works.
# *   **Real-world Examples:** Optimization of engineering designs (e.g., airplane wing shapes, antenna design), financial modeling, scheduling problems, hyperparameter tuning for machine learning models, robot motion planning.
#
# **Comparison:** Evolutionary computation is less about understanding or mimicking intelligence directly, and more about finding optimal solutions through a process analogous to natural trial-and-error. It's often used *within* other AI systems for specific optimization tasks.
#
# ---
#
# ### Path 4: Probabilistic / Statistical AI (Uncertainty Handling)
#
# *   **Core Idea/Philosophy:** This path acknowledges that the real world is inherently uncertain. It focuses on reasoning and making decisions using probability theory and statistics to quantify and manage uncertainty.
# *   **How it Works:**
#     *   **Probabilistic Models:** Systems are built to represent relationships between variables using probabilities (e.g., "the probability of rain given cloudy skies").
#     *   **Bayesian Inference:** Updates beliefs about events as new evidence becomes available.
#     *   **Statistical Analysis:** Uses statistical methods to analyze data, identify patterns, and make predictions under uncertainty.
# *   **Key Techniques:** Bayesian Networks, Hidden Markov Models (HMMs), Kalman Filters, Markov Decision Processes (MDPs).
# *   **Strengths:**
#     *   **Quantifies Uncertainty:** Provides a principled way to deal with incomplete or noisy information.
#     *   **Robustness:** Can make reasonable decisions even when inputs are ambiguous.
#     *   **Strong Theoretical Foundation:** Based on well-established mathematical principles.
#     *   **Integration:** Can be integrated with symbolic (e.g., probabilistic logic) or connectionist (e.g., Bayesian deep learning) approaches.
# *   **Weaknesses:**
#     *   **Computational Complexity:** Exact inference in large probabilistic models can be intractable.
#     *   **Parameter Estimation:** Requires accurate probability estimates, which can be challenging to obtain.
#     *   **Assumptions:** Many models rely on independence assumptions that may not hold in the real world.
# *   **Real-world Examples:** Medical diagnosis, spam filtering, speech recognition, financial fraud detection, tracking and navigation systems, robotics (sensor fusion).
#
# **Comparison:** Probabilistic AI provides a framework for reasoning about the world when information is imperfect. It often complements other approaches by adding a layer of uncertainty management, allowing systems to make more robust and informed decisions.
#
# ---
#
# ### Path 5: Embodied AI / Robotics (Interaction with the World)
#
# *   **Core Idea/Philosophy:** This path argues that intelligence is not just about abstract reasoning but is deeply intertwined with a body, perception, and interaction with the physical world. It emphasizes learning through doing and experiencing.
# *   **How it Works:**
#     *   **Sensors and Actuators:** Robots use sensors (cameras, lidar, touch) to perceive their environment and actuators (motors, grippers) to interact with it.
#     *   **Reinforcement Learning:** Often used to train robots to learn optimal actions through trial and error, based on rewards and penalties in their environment.
#     *   **Perception and Control:** Integrates computer vision, path planning, motor control, and human-robot interaction.
#     *   **Sim-to-Real Transfer:** Training AI in simulations and then deploying it in the real world.
# *   **Key Techniques:** Reinforcement Learning, Computer Vision, Sensor Fusion, Motion Planning, Haptic Feedback.
# *   **Strengths:**
#     *   **Practical Skills:** Develops intelligence grounded in real-world actions and consequences.
#     *   **Adaptability:** Robots can learn to adapt to dynamic and unpredictable environments.
#     *   **Real-world Impact:** Directly enables automation and interaction in physical spaces.
#     *   **Grounding:** Provides a basis for understanding concepts through physical experience.
# *   **Weaknesses:**
#     *   **High Cost & Complexity:** Robotics is expensive, and engineering robust physical systems is challenging.
#     *   **Safety Concerns:** Interactions with the physical world pose risks.
#     *   **Sim-to-Real Gap:** It's often difficult to transfer learning from perfect simulations to the messy real world.
#     *   **Computational Demands:** Real-time processing of sensory data and complex control is computationally intensive.
# *   **Real-world Examples:** Autonomous vehicles, industrial robots (manufacturing, logistics), humanoid robots, surgical robots, drones for inspection and delivery.
#
# **Comparison:** Embodied AI isn't necessarily a *different* form of "intelligence" but rather a different *context* for it. It heavily leverages techniques from machine learning (especially reinforcement learning) and symbolic AI (for planning) but applies them to the unique challenges of physical interaction and perception.
#
# ---
#
# ## Hybrid Approaches: The Future is Blended
#
# In reality, the most powerful and sophisticated AI systems today often combine elements from multiple solution paths. This is known as **Hybrid AI**.
#
# *   **Neuro-Symbolic AI:** Attempts to combine the learning capabilities of neural networks with the reasoning and explainability of symbolic AI. For example, a neural network might learn patterns, and then a symbolic system uses those patterns for logical inference, or vice-versa.
# *   **Reinforcement Learning with Planning:** An embodied agent might use a reinforcement learning policy to navigate, but a symbolic planner to set high-level goals.
# *   **Probabilistic Deep Learning:** Integrating Bayesian methods into deep learning to quantify uncertainty in predictions.
#
# These hybrid approaches aim to leverage the strengths of each paradigm while mitigating their weaknesses, moving closer to more robust, intelligent, and understandable systems.
#
# ---
#
# ## Conclusion
#
# Artificial Intelligence is a quest, not a single destination. The "solution paths" we've explored—Symbolic, Connectionist, Evolutionary, Probabilistic, and Embodied—represent fundamental shifts in how researchers have conceived and built intelligent machines.
#
# *   **Symbolic AI** provided the early foundation for explicit reasoning.
# *   **Connectionism/Machine Learning** revolutionized perception and pattern recognition through data.
# *   **Evolutionary Computation** offered a way to search vast problem spaces.
# *   **Probabilistic AI** gave us tools to handle uncertainty.
# *   **Embodied AI** grounds intelligence in physical interaction.
#
# No single path has proven to be the ultimate answer for General AI. Instead, the field is increasingly recognizing the value of **integrating these diverse approaches**, building systems that can reason symbolically, learn from data, adapt through evolution, handle uncertainty, and interact effectively with the physical world. The comparison of these paths highlights not just their individual merits, but also the rich, multifaceted nature of intelligence itself.

# %% [markdown]
# ## 5. Zero-Shot Prompting

# %%
zero_shot_response = call_gemini(
    "Explain Artificial Intelligence in simple terms."
)
print(zero_shot_response)
# Out:
# Imagine you're trying to teach a computer to be smart, almost like a human.
#
# **Artificial Intelligence (AI) is essentially making computers and machines think and act in ways that usually require human intelligence.**
#
# It's about getting them to:
#
# *   **Learn from experience:** Just like a child learns not to touch a hot stove after doing it once, AI systems can learn from data and past interactions.
# *   **Understand and respond to language:** Like Siri, Alexa, or chatbots you talk to online.
# *   **Recognize patterns:** Identifying faces in photos, spotting spam emails, or recommending movies you might like.
# *   **Solve problems:** Finding the fastest route on a map, playing complex games, or diagnosing diseases.
# *   **Make decisions:** Based on the information they've gathered and learned.
#
# **How does it work (simply)?**
#
# Instead of telling a computer every single step for every possible scenario, we design programs that can **learn from examples** and **figure things out for themselves.** We feed them massive amounts of data (like pictures, text, numbers), and the AI finds patterns and rules within that data, allowing it to make predictions or take actions.
#
# **Think of AI as a super-smart, incredibly fast student:**
#
# *   You give it tons of textbooks (data).
# *   It studies them diligently (processes data).
# *   It finds connections and answers questions based on what it learned (makes predictions/decisions).
#
# **Examples you use every day:**
#
# *   **Siri, Alexa, Google Assistant:** Understanding your voice commands.
# *   **Netflix or Spotify recommendations:** Suggesting what you might like next.
# *   **Google Maps/Waze:** Finding the best route and avoiding traffic.
# *   **Email spam filters:** Identifying and blocking junk mail.
# *   **Facial recognition:** Unlocking your phone or tagging friends in photos.
# *   **Chatbots:** Answering your questions on a website.
#
# In short, AI is the technology that allows machines to mimic human intelligence to perform tasks that once only humans could do.

# %% [markdown]
# ## 6. Few-Shot Prompting

# %%
few_shot_response = call_gemini(
    """Example 1: AI helps computers think.
Example 2: AI is used in chatbots.
Now explain Artificial Intelligence."""
)
print(few_shot_response)
# Out:
# Artificial Intelligence (AI) is all about making computers and machines **think and learn in ways that imitate human intelligence.**
#
# Instead of just following rigid instructions, AI allows machines to:
# *   **Understand** information.
# *   **Learn** from data and experience.
# *   **Solve problems**.
# *   **Make decisions**.
#
# *   **Drawing on your first example, 'AI helps computers think':** This means AI gives computers the ability to process information, recognize patterns, and come to conclusions, much like a human brain does, rather than just performing predefined calculations. They can *reason* and *adapt*.
#
# *   **From your second example, 'AI is used in chatbots':** This shows AI's capability in understanding human language (natural language processing), interpreting what you say, and generating relevant responses. It makes the computer seem like it's having a natural conversation with you, understanding context and intent.
#
# Essentially, AI is the technology that empowers machines to perform tasks that typically require human cognitive abilities.

# %% [markdown]
# ## 7. Comparison & Analysis

# %% [markdown]
# ### Comparison Table
#
# | Approach | Characteristics | Applications |
# |--------|----------------|--------------|
# | Interview | Concise, formal | Interviews, exams |
# | CoT | Step-by-step reasoning | Problem solving |
# | ToT | Multiple reasoning paths | Complex decisions |
# | Zero-shot | No examples | General queries |
# | Few-shot | Guided by examples | Consistent outputs |
