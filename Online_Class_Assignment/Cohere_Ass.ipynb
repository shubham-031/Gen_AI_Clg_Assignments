# %%
# !pip install openAI
# !pip install langchain
# !pip install Cohere
# !pip install langchain_community
# Out:
# Requirement already satisfied: openAI in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (2.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from openAI) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openAI) (2.10)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openAI) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openAI) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openAI) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->openAI) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->openAI) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->openAI) (0.4.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openAI) (0.4.6)
# Requirement already satisfied: langchain in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.2.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.3.0)
# Collecting Cohere
#   Downloading cohere-5.20.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from Cohere)
#   Downloading fastavro-1.12.1-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (0.28.1)
# Requirement already satisfied: pydantic>=1.9.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (2.12.5)
# Requirement already satisfied: pydantic-core>=2.18.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (2.32.5)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (0.22.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from Cohere)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from Cohere) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->Cohere) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->Cohere) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->Cohere) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->Cohere) (2025.11.12)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from tokenizers<1,>=0.15->Cohere) (0.36.0)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (2025.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (4.67.1)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->Cohere) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->Cohere) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->Cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.9.2->Cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.9.2->Cohere) (0.4.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->Cohere) (0.4.6)
# Downloading cohere-5.20.2-py3-none-any.whl (318 kB)
# Downloading fastavro-1.12.1-cp311-cp311-win_amd64.whl (450 kB)
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, fastavro, Cohere
#
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    ------------- -------------------------- 1/3 [fastavro]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    -------------------------- ------------- 2/3 [Cohere]
#    ---------------------------------------- 3/3 [Cohere]
#
# Successfully installed Cohere-5.20.2 fastavro-1.12.1 types-requests-2.32.4.20260107
# Requirement already satisfied: langchain_community in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (1.2.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.5.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain_community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)

# %%
from dotenv import load_dotenv
import os

load_dotenv()

os.environ["COHERE_API_KEY"] = os.getenv("COHERE_API_KEY")

# %%
# !pip install langchain-cohere
# Out:
# Collecting langchain-cohere
#   Downloading langchain_cohere-0.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: cohere<6.0,>=5.18.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere) (5.20.2)
# Requirement already satisfied: langchain-community<0.5.0,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere) (0.4.1)
# Requirement already satisfied: langchain-core<2.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere) (1.2.5)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-cohere) (2.12.5)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from langchain-cohere)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (1.12.1)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.5)
# Requirement already satisfied: tokenizers<1,>=0.15 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.22.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.4.20260107)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (4.15.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.0.45)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.5.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.0.0->langchain-cohere) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.25.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (4.12.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (2.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.36.0)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (2025.12.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (4.67.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.1.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.4.6)
# Downloading langchain_cohere-0.5.0-py3-none-any.whl (42 kB)
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Installing collected packages: types-pyyaml, langchain-cohere
#
#    -------------------- ------------------- 1/2 [langchain-cohere]
#    -------------------- ------------------- 1/2 [langchain-cohere]
#    -------------------- ------------------- 1/2 [langchain-cohere]
#    -------------------- ------------------- 1/2 [langchain-cohere]
#    -------------------- ------------------- 1/2 [langchain-cohere]
#    ---------------------------------------- 2/2 [langchain-cohere]
#
# Successfully installed langchain-cohere-0.5.0 types-pyyaml-6.0.12.20250915

# %%
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

llm = ChatCohere()
messages = [
    HumanMessage(
        content="What are uses of cohere ?"
    )
]
result = llm.invoke(messages)
print(result.content)
# Out:
# Cohere is an AI company that provides natural language processing (NLP) models and tools to help developers and businesses build intelligent applications. Here are some of the primary uses of Cohere's technology:
#
# 1. **Text Generation and Completion**:
#    - **Content Creation**: Generate articles, blog posts, product descriptions, and other forms of written content.
#    - **Chatbots and Virtual Assistants**: Power conversational agents that can interact with users in a natural and engaging way.
#
# 2. **Text Classification**:
#    - **Sentiment Analysis**: Determine the sentiment (positive, negative, neutral) of text data, useful for customer feedback analysis.
#    - **Topic Classification**: Categorize text into predefined topics or genres, aiding in content organization and retrieval.
#    - **Spam Detection**: Identify and filter out unwanted or malicious content.
#
# 3. **Text Embeddings**:
#    - **Semantic Search**: Enable search engines to understand the meaning behind queries, improving search relevance.
#    - **Recommendation Systems**: Generate embeddings for items and users to provide personalized recommendations.
#    - **Clustering and Similarity Analysis**: Group similar texts together for analysis or organization.
#
# 4. **Question Answering**:
#    - **FAQ Systems**: Automatically answer frequently asked questions based on a knowledge base.
#    - **Educational Tools**: Assist in creating interactive learning experiences by answering student queries.
#
# 5. **Summarization**:
#    - **Document Summarization**: Condense long documents into shorter, more manageable summaries.
#    - **News Aggregation**: Provide concise summaries of news articles for quick consumption.
#
# 6. **Translation**:
#    - **Multilingual Support**: Translate text between different languages, facilitating global communication.
#
# 7. **Custom Model Training**:
#    - **Fine-Tuning**: Adapt pre-trained models to specific tasks or domains using custom datasets.
#    - **Domain-Specific Applications**: Develop models tailored to specific industries, such as healthcare, finance, or legal.
#
# 8. **Data Analysis and Insights**:
#    - **Trend Analysis**: Identify trends and patterns in large volumes of text data.
#    - **Customer Insights**: Gain deeper understanding of customer preferences and behaviors through text analysis.
#
# 9. **Automation**:
#    - **Workflow Automation**: Automate repetitive text-based tasks, such as data entry, report generation, and email responses.
#    - **Content Moderation**: Automatically moderate user-generated content to ensure compliance with community guidelines.
#
# 10. **Research and Development**:
#     - **Academic Research**: Utilize Cohere's models for NLP research and experimentation.
#     - **Prototyping**: Quickly prototype AI-driven applications and features.
#
# Cohere's platform is designed to be flexible and scalable, making it suitable for a wide range of applications across various industries. Whether you're a developer looking to integrate advanced NLP capabilities into your application or a business seeking to leverage AI for better decision-making, Cohere provides the tools and infrastructure to achieve your goals.

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (2.3.5)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (25.0)

# %%
# ---- Semantic Search with LangChain + Cohere ----

from langchain_cohere import CohereEmbeddings
from langchain_community.vectorstores import FAISS

documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with many layers",
    "Fruits like apples and bananas are healthy",
    "Football is a popular sport worldwide"
]

# Create embeddings
embeddings = CohereEmbeddings(
    model="embed-english-v3.0"
)

# Build vector store
vectorstore = FAISS.from_texts(documents, embeddings)

# Query
query = "Explain deep learning"

# Semantic search
results = vectorstore.similarity_search(query, k=2)

# Output
for i, doc in enumerate(results):
    print(f"Result {i+1}: {doc.page_content}")
# Out:
# Result 1: Deep learning uses neural networks with many layers
# Result 2: Machine learning is a subset of artificial intelligence

# %%
# ---- Sentiment Analysis with LangChain + Cohere ----

from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage, SystemMessage



llm = ChatCohere(
    model="command-r7b-12-2024",
    temperature=0
)

messages = [
    SystemMessage(
        content=(
            "You are a sentiment analysis engine. "
            "Classify the sentiment strictly as Positive, Negative, or Neutral."
        )
    ),
    HumanMessage(
        content="The product quality is amazing but the delivery was very slow."
    )
]

result = llm.invoke(messages)

print(result.content)
# Out:
# The sentiment of this statement is **Negative**.
