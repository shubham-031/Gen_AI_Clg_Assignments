# %%
from dotenv import load_dotenv
import os

load_dotenv() 
os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make decisions.

# %%
from google import genai

client = genai.Client()

result = client.models.embed_content(
        model="gemini-embedding-001",
        contents="What is the meaning of life?"
)

print(result.embeddings)
# Out:
# [ContentEmbedding(
#   values=[
#     -0.022374554,
#     -0.004560777,
#     0.013309286,
#     -0.0545072,
#     -0.02090443,
#     <... 3067 more items ...>,
#   ]
# )]

# %%
from google import genai
from google.genai import types
import wave

# Set up the wave file to save the output:
def wave_file(filename, pcm, channels=1, rate=24000, sample_width=2):
   with wave.open(filename, "wb") as wf:
      wf.setnchannels(channels)
      wf.setsampwidth(sample_width)
      wf.setframerate(rate)
      wf.writeframes(pcm)

client = genai.Client()

response = client.models.generate_content(
   model="gemini-2.5-flash-preview-tts",
   contents="Say cheerfully: Have a wonderful day!",
   config=types.GenerateContentConfig(
      response_modalities=["AUDIO"],
      speech_config=types.SpeechConfig(
         voice_config=types.VoiceConfig(
            prebuilt_voice_config=types.PrebuiltVoiceConfig(
               voice_name='Kore',
            )
         )
      ),
   )
)

data = response.candidates[0].content.parts[0].inline_data.data

file_name='out.wav'
wave_file(file_name, data) # Saves the file to current directory

# %%
from IPython.display import Audio, display

display(Audio("out.wav"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google import genai
from google.genai import types
import httpx

client = genai.Client()

doc_url = "https://discovery.ucl.ac.uk/id/eprint/10089234/1/343019_3_art_0_py4t4l_convrt.pdf"

# Retrieve and encode the PDF byte
doc_data = httpx.get(doc_url).content

prompt = "Summarize this document"
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[
        types.Part.from_bytes(
            data=doc_data,
            mime_type='application/pdf',
        ),
        prompt
    ]
)

print(response.text)
# Out:
# This document describes **AlphaFold**, a deep-learning-based system developed by DeepMind to predict the three-dimensional structure of proteins from their amino acid sequences.
#
# ### **Core Innovation**
# The primary advancement of AlphaFold over previous methods is the transition from predicting simple binary "contacts" (whether two residues are near each other) to predicting **discrete probability distributions of distances** between every pair of residues in a protein (a "distogram").
#
# ### **Key Methodology**
# *   **Deep Learning Architecture:** AlphaFold uses a deep two-dimensional dilated convolutional residual network (consisting of 220 residual blocks) trained on known structures from the Protein Data Bank (PDB).
# *   **Input Features:** The network takes the protein sequence and features derived from **Multiple Sequence Alignments (MSA)** to leverage evolutionary information.
# *   **Potential Minimization:** The system constructs a "potential of mean force" based on the predicted distance and torsion angle distributions. Unlike previous methods that relied on complex stochastic sampling (like simulated annealing), AlphaFold realizes the protein structure by optimizing this potential using a simple **gradient descent algorithm (L-BFGS)**.
#
# ### **Performance and Results**
# AlphaFold was benchmarked during **CASP13** (the 13th Critical Assessment of Protein Structure Prediction), a prestigious blind assessment in the field:
# *   **High Accuracy:** It achieved high-accuracy structures (TM-scores of 0.7 or higher) for **24 out of 43** "free modelling" (FM) domains—cases where no homologous protein structure is known. For comparison, the next best system achieved this for only 14 out of 43 domains.
# *   **Ranking:** AlphaFold ranked first in the FM category, achieving a summed z-score of 52.8 compared to 36.6 for the second-place group.
# *   **Biological Relevance:** The document demonstrates that AlphaFold’s accuracy enables better identification of protein folds in databases like CATH, more accurate modeling of ligand-binding pockets, and improved prediction of protein-protein interaction interfaces.
#
# ### **Conclusion**
# The authors conclude that AlphaFold represents a significant leap in protein structure prediction. By providing more accurate models for proteins with unknown structures, the system can provide deeper insights into biological functions and malfunctions, potentially accelerating drug discovery and basic biological research.
